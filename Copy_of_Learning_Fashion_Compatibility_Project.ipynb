# %% [markdown]
# <a href="https://colab.research.google.com/github/elirangerbi/Learning-Fashion-Compatibility-Project/blob/main/Copy_of_Learning_Fashion_Compatibility_Project.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install -U -q PyDrive

# %%
# !pip install gdown

# %%
# write stdout and pipe to extract
# !gdown https://drive.google.com/uc?id=0B9P1L--7Wd2vNm9zMTJWOGxobkU -O - --quiet | tar zxvf -
# !ls 20150428_collected_images/
# Out:
# 20150428_collected_images/
# 20150428_collected_images/crayola_64_ct/
# 20150428_collected_images/crayola_64_ct/front0026.jpg
# 20150428_collected_images/crayola_64_ct/back0021.jpg
# 20150428_collected_images/crayola_64_ct/front0001.jpg
# 20150428_collected_images/crayola_64_ct/front0024.jpg
# 20150428_collected_images/crayola_64_ct/front0020.jpg
# 20150428_collected_images/crayola_64_ct/back0030.jpg
# 20150428_collected_images/crayola_64_ct/back0013.jpg
# 20150428_collected_images/crayola_64_ct/front0007.jpg
# 20150428_collected_images/crayola_64_ct/back0028.jpg
# 20150428_collected_images/crayola_64_ct/back0012.jpg
# 20150428_collected_images/crayola_64_ct/front0009.jpg
# 20150428_collected_images/crayola_64_ct/front0013.jpg
# 20150428_collected_images/crayola_64_ct/front0021.jpg
# 20150428_collected_images/crayola_64_ct/back0019.jpg
# 20150428_collected_images/crayola_64_ct/back0014.jpg
# 20150428_collected_images/crayola_64_ct/front0028.jpg
# ...
